# %%
import pandas as pd

# %%
data_path = "../data/companies.csv"
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#    company_id                                       company_name  \
# 0    41273639                    MH MATERIAIS DE CONSTRUCAO LTDA
# 1    41274138             CLINICA ESTETICA CAXIAS DO SUL RS LTDA
# 2    41274505                    G P CONSTRUCOES E SERVICOS LTDA
# 3    41274745  UNICREDIT BANK SAO PAULO CONSULTORIA UNIPESSOA...
# 4    41274856             PRODUCON PRODUTOS PARA CONSTRUCAO LTDA
#
#                                legal_nature  \
# 0  Limited Liability Business Company (LLC)
# 1  Limited Liability Business Company (LLC)
# 2  Limited Liability Business Company (LLC)
# 3  Limited Liability Business Company (LLC)
# 4  Limited Liability Business Company (LLC)
#
#                         owner_qualification  capital_stock      company_size
# 0  Managing Partner / Partner-Administrator      1000000.0  small-enterprise
# 1  Managing Partner / Partner-Administrator       200000.0  micro-enterprise
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141332 entries, 0 to 141331
# Data columns (total 6 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   company_id           141332 non-null  int64
#  1   company_name         141332 non-null  object
#  2   legal_nature         141332 non-null  object
#  3   owner_qualification  141332 non-null  object
#  4   capital_stock        141332 non-null  float64
#  5   company_size         141332 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.5+ MB
