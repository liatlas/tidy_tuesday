# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 import pandas as pd
# ----> 2 import nltk
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# File /usr/lib/python3.14/site-packages/nltk/__init__.py:180
#     177 else:
#     178     from nltk import cluster
# --> 180 from nltk.downloader import download, download_shell
#     182 try:
#     183     import tkinter
#
# File /usr/lib/python3.14/site-packages/nltk/downloader.py:2475
#    2465             pass
#    2468 ######################################################################
#    2469 # Main:
#    2470 ######################################################################
#    (...)   2473
#    2474 # Aliases
# -> 2475 _downloader = Downloader()
#    2476 download = _downloader.download
#    2479 def download_shell():
#
# ...

# %%
data_path = "../data/christmas_novels.csv"
text_path = "../data/christmas_novel_text.csv"
text_df = pd.read_csv(text_path)
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#    gutenberg_id                                              title  \
# 0            46  A Christmas Carol in Prose; Being a Ghost Stor...
# 1          1902  The Old Peabody Pew: A Christmas Romance of a ...
# 2          2731           The Christmas Books of Mr. M.A. Titmarsh
# 3          4384      The Lost Word: A Christmas Legend of Long Ago
# 4          8694  The Abbot's Ghost, or Maurice Treherne's Tempt...
#
#    gutenberg_author_id
# 0                   37
# 1                  266
# 2                  313
# 3                  362
# 4                  102

# %%
text_df.head(50)
# Out:
#     gutenberg_id                                               text
# 0             46                                  A CHRISTMAS CAROL
# 1             46                                                NaN
# 2             46                                           IN PROSE
# 3             46                                              BEING
# 4             46                         A Ghost Story of Christmas
# 5             46                                                NaN
# 6             46                                 by Charles Dickens
# 7             46                                                NaN
# 8             46                                                NaN
# 9             46                                                NaN
# 10            46                                            PREFACE
# 11            46                                                NaN
# 12            46    I HAVE endeavoured in this Ghostly little book,
# ...

# %%
k
