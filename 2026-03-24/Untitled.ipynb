# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("pi_digits.csv", index_col="digit_position")

# %%
df
# Out:
#                 digit
# digit_position
# 1                   3
# 2                   1
# 3                   4
# 4                   1
# 5                   5
# ...               ...
# 999997              5
# 999998              8
# 999999              1
# 1000000             5
# 1000001             1
#
# [1000001 rows x 1 columns]

# %%
sns.histplot(data=df.head(10000), x="digit")
# Out:
# <Axes: xlabel='digit', ylabel='Count'>
