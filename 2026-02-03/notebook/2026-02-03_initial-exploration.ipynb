# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = "../data/edible_plants.csv"

# %%
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#         taxonomic_name       common_name cultivation  \
# 0        Pisum sativum               Pea      Legume
# 1  Phaseolus coccineus    Beans (Runner)      Legume
# 2    Phaseolus vulgari    Beans (French)      Legume
# 3           Vicia faba     Beans (Broad)      Legume
# 4    Brassica oleracea  Cabbage (Spring)      Legume
#
#                             sunlight      water  preferred_ph_lower  \
# 0                           Full sun  Very High                 6.0
# 1                           Full sun     Medium                 6.0
# 2                           Full sun     Medium                 6.0
# 3  Full sun/partial shade/full shade   Very Low                 6.0
# 4                           Full sun       High                 6.0
#
#    preferred_ph_upper nutrients                          soil    season  \
# 0                 7.5    Medium                         Loamy    Annual
# 1                 6.8    Medium                Loamy and clay    Annual
# ...

# %%
df.groupby('sunlight')['temperature_class'].value_counts()
# Out:
# sunlight                            temperature_class
# Full sun                            Hardy                45
#                                     Tender               26
#                                     Very hardy           10
#                                     Half hardy            4
#                                     Very tender           2
# Full sun/partial shade              Hardy                19
#                                     Very hardy           10
#                                     Half hardy            8
#                                     Tender                6
#                                     Very hard             1
# Full sun/partial shade/full shade   Hardy                 2
# Partial shade                       Tender                3
#                                     Hardy                 1
#                                     Very hardy            1
# full sun/partial shade/ full shade  Tender                1
# ...

# %%
df.groupby('temperature_class')['sunlight'].value_counts()
# Out:
# temperature_class  sunlight
# Half hardy         Full sun/partial shade                 8
#                    Full sun                               4
# Hardy              Full sun                              45
#                    Full sun/partial shade                19
#                    Full sun/partial shade/full shade      2
#                    Partial shade                          1
# Tender             Full sun                              26
#                    Full sun/partial shade                 6
#                    Partial shade                          3
#                    full sun/partial shade/ full shade     1
#                    partial shade                          1
# Very hard          Full sun/partial shade                 1
# Very hardy         Full sun                              10
#                    Full sun/partial shade                10
#                    Partial shade                          1
# ...

# %%
sns.histplot(df, x='sunlight', hue='temperature_class')
# Out:
# <Axes: xlabel='sunlight', ylabel='Count'>

# %%
sns.histplot(df, x='temperature_class')
# Out:
# <Axes: xlabel='temperature_class', ylabel='Count'>

# %%
sns.histplot(df, x='temperature_class', hue='sunlight')
# Out:
# <Axes: xlabel='temperature_class', ylabel='Count'>

# %%
from statsmodels.graphics.mosaicplot import mosaic
